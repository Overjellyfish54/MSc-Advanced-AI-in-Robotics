# %%
# !pip install opencv-python
# !pip install mediapipe
# Out:
# Requirement already satisfied: opencv-python in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: mediapipe in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (0.10.18)
# Requirement already satisfied: absl-py in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: jaxlib in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: matplotlib in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (3.9.3)
# Requirement already satisfied: numpy<2 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (4.25.5)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from jax->mediapipe) (0.5.0)
# Requirement already satisfied: opt-einsum in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from jax->mediapipe) (8.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (6.4.5)
# Requirement already satisfied: pycparser in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: zipp>=3.20 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.6->jax->mediapipe) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\callu\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)

# %%
import cv2
import mediapipe as mp

# %%
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

# %% [markdown]
# # 2. Feed Detections

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # Make Detections
        results = holistic.process(image)q
        
        # Recolor image back to BGR for rendering
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                
        # Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

        # Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

        # Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
                        
        cv2.imshow('Real Time Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
mp_holistic.POSE_CONNECTIONS
# Out:
# frozenset({(0, 1),
#            (0, 4),
#            (1, 2),
#            (2, 3),
#            (3, 7),
#            (4, 5),
#            (5, 6),
#            (6, 8),
#            (9, 10),
#            (11, 12),
#            (11, 13),
#            (11, 23),
#            (12, 14),
#            (12, 24),
#            (13, 15),
#            (14, 16),
#            (15, 17),
#            (15, 19),
#            (15, 21),
#            (16, 18),
#            (16, 20),
#            (16, 22),
#            (17, 19),
#            (18, 20),
#            (23, 24),
#            (23, 25),
#            (24, 26),
#            (25, 27),
#            (26, 28),
#            (27, 29),
#            (27, 31),
#            (28, 30),
#            (28, 32),
#            (29, 31),
#            (30, 32)})

# %%
mp_drawing.DrawingSpec(color=(0,0,255), thickness=2, circle_radius=2)
# Out:
# DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2)

# %%
mp_drawing.draw_landmarks??
# Out:
# Signature:
# mp_drawing.draw_landmarks(
#     image: numpy.ndarray,
#     landmark_list: mediapipe.framework.formats.landmark_pb2.NormalizedLandmarkList,
#     connections: Optional[List[Tuple[int, int]]] = None,
#     landmark_drawing_spec: Union[mediapipe.python.solutions.drawing_utils.DrawingSpec, Mapping[int, mediapipe.python.solutions.drawing_utils.DrawingSpec], NoneType] = DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
#     connection_drawing_spec: Union[mediapipe.python.solutions.drawing_utils.DrawingSpec, Mapping[Tuple[int, int], mediapipe.python.solutions.drawing_utils.DrawingSpec]] = DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2),
#     is_drawing_landmarks: bool = True,
# )
# Source:
# def draw_landmarks(
#     image: np.ndarray,
#     landmark_list: landmark_pb2.NormalizedLandmarkList,
#     connections: Optional[List[Tuple[int, int]]] = None,
#     landmark_drawing_spec: Optional[
#         Union[DrawingSpec, Mapping[int, DrawingSpec]]
#     ] = DrawingSpec(color=RED_COLOR),
#     connection_drawing_spec: Union[
#         DrawingSpec, Mapping[Tuple[int, int], DrawingSpec]
#     ] = DrawingSpec(),
#     is_drawing_landmarks: bool = True,
# ):
#   """Draws the landmarks and the connections on the image.
#
#   Args:
#     image: A three channel BGR image represented as numpy ndarray.
#     landmark_list: A normalized landmark list proto message to be annotated on
#       the image.
#     connections: A list of landmark index tuples that specifies how landmarks to
#       be connected in the drawing.
#     landmark_drawing_spec: Either a DrawingSpec object or a mapping from hand
#       landmarks to the DrawingSpecs that specifies the landmarks' drawing
#       settings such as color, line thickness, and circle radius. If this
#       argument is explicitly set to None, no landmarks will be drawn.
#     connection_drawing_spec: Either a DrawingSpec object or a mapping from hand
#       connections to the DrawingSpecs that specifies the connections' drawing
#       settings such as color and line thickness. If this argument is explicitly
#       set to None, no landmark connections will be drawn.
#     is_drawing_landmarks: Whether to draw landmarks. If set false, skip drawing
#       landmarks, only contours will be drawed.
#
#   Raises:
#     ValueError: If one of the followings:
#       a) If the input image is not three channel BGR.
#       b) If any connetions contain invalid landmark index.
#   """
#   if not landmark_list:
#     return
#   if image.shape[2] != _BGR_CHANNELS:
#     raise ValueError('Input image must contain three channel bgr data.')
#   image_rows, image_cols, _ = image.shape
#   idx_to_coordinates = {}
#   for idx, landmark in enumerate(landmark_list.landmark):
#     if ((landmark.HasField('visibility') and
#          landmark.visibility < _VISIBILITY_THRESHOLD) or
#         (landmark.HasField('presence') and
#          landmark.presence < _PRESENCE_THRESHOLD)):
#       continue
#     landmark_px = _normalized_to_pixel_coordinates(landmark.x, landmark.y,
#                                                    image_cols, image_rows)
#     if landmark_px:
#       idx_to_coordinates[idx] = landmark_px
#   if connections:
#     num_landmarks = len(landmark_list.landmark)
#     # Draws the connections if the start and end landmarks are both visible.
#     for connection in connections:
#       start_idx = connection[0]
#       end_idx = connection[1]
#       if not (0 <= start_idx < num_landmarks and 0 <= end_idx < num_landmarks):
#         raise ValueError(f'Landmark index is out of range. Invalid connection '
#                          f'from landmark #{start_idx} to landmark #{end_idx}.')
#       if start_idx in idx_to_coordinates and end_idx in idx_to_coordinates:
#         drawing_spec = connection_drawing_spec[connection] if isinstance(
#             connection_drawing_spec, Mapping) else connection_drawing_spec
#         cv2.line(image, idx_to_coordinates[start_idx],
#                  idx_to_coordinates[end_idx], drawing_spec.color,
#                  drawing_spec.thickness)
#   # Draws landmark points after finishing the connection lines, which is
#   # aesthetically better.
#   if is_drawing_landmarks and landmark_drawing_spec:
#     for idx, landmark_px in idx_to_coordinates.items():
#       drawing_spec = landmark_drawing_spec[idx] if isinstance(
#           landmark_drawing_spec, Mapping) else landmark_drawing_spec
#       # White circle border
#       circle_border_radius = max(drawing_spec.circle_radius + 1,
#                                  int(drawing_spec.circle_radius * 1.2))
#       cv2.circle(image, landmark_px, circle_border_radius, WHITE_COLOR,
#                  drawing_spec.thickness)
#       # Fill color into the circle
#       cv2.circle(image, landmark_px, drawing_spec.circle_radius,
#                  drawing_spec.color, drawing_spec.thickness)
# File:      c:\users\callu\appdata\local\programs\python\python39\lib\site-packages\mediapipe\python\solutions\drawing_utils.py
# Type:      function
